# %%
import os
path_to_directory="C:/Users/91798/Downloads/NATOPS/NATOPS/"
files = [arff for arff in os.listdir(path_to_directory) if arff.endswith(".arff")]

def toCsv(content): 
    data = False
    header = ""
    newContent = []
    for line in content:
        if not data:
            if "@attribute" in line:
                attri = line.split()
                columnName = attri[attri.index("@attribute")+1]
                header = header + columnName + ","
            elif "@data" in line:
                data = True
                header = header[:-1]
                header += '\n'
                newContent.append(header)
        else:
            newContent.append(line)
    return newContent

for i,file in enumerate(files):
    with open(path_to_directory+file , "r") as inFile:
        content = inFile.readlines()
        name,ext = os.path.splitext(inFile.name)
        new = toCsv(content)
        with open(name+".csv", "w") as outFile:
            outFile.writelines(new)

# %%
csv_files = [fcsv for fcsv in os.listdir(path_to_directory) if fcsv.endswith(".csv")]

# %%
len(csv_files)
# Out:
# 50

# %%
import pandas as pd

directory = 'C:/Users/91798/Downloads/NATOPS/NATOPS/'
data_frames = []

for filename in csv_files:
    if filename.endswith(".csv"):
        file_path = os.path.join(directory, filename)
        df = pd.read_csv(file_path)
        data_frames.append(df)

# %%
reshaped_data_frames = []
for i in range(len(data_frames)):
    temp = data_frames[i].stack().reset_index(drop=True).to_frame()
    reshaped_data_frames.append(temp)

# %%
reshaped_data_frames[1].shape
# Out:
# (9360, 1)

# %%
reshaped_data_frames[0]
# Out:
#              0
# 0     0.631310
# 1     0.632066
# 2     0.633518
# 3     0.634159
# 4     0.634378
# ...        ...
# 9355  0.630602
# 9356  0.607822
# 9357  0.600801
# 9358  0.597154
# 9359  4.000000
#
# [9360 rows x 1 columns]

# %%
big_data_frame1 = reshaped_data_frames[0]

# %%
big_data_frame1.rename(columns = {0:'feature1'}, inplace = True)

# %%
big_data_frame1.head()
# Out:
#    feature1
# 0  0.631310
# 1  0.632066
# 2  0.633518
# 3  0.634159
# 4  0.634378

# %%
temp_column = reshaped_data_frames[2]
data1 = pd.concat([big_data_frame1,temp_column], axis = 1)

# %%
data1.head()
# Out:
#    feature1         0
# 0  0.631310 -0.807240
# 1  0.632066 -0.807258
# 2  0.633518 -0.807240
# 3  0.634159 -0.809020
# 4  0.634378 -0.809834

# %%
v = 0
name = ['feature2','feature3','feature4','feature5','feature6','feature7','feature8','feature9','feature10','feature11','feature12','feature13','feature14','feature15','feature16','feature17','feature18','feature19','feature20','feature21','feature22','feature23','feature24','feature25','feature26']
for i in range(3,50):
    if i%2 == 0:
        temp_column = reshaped_data_frames[i]
        data1 = pd.concat([data1,temp_column], axis = 1)
        data1.rename(columns = {0:name[v]}, inplace = True)
        v+=1

# %%
data1.head()
# Out:
#    feature1  feature2  feature2  feature3  feature4  feature5  feature6  \
# 0  0.631310 -0.807240 -0.279330 -0.630195 -1.451361 -0.465686  0.665998
# 1  0.632066 -0.807258 -0.278007 -0.626388 -1.464355 -0.474674  0.666855
# 2  0.633518 -0.807240 -0.274849 -0.642930 -1.462434 -0.474046  0.669992
# 3  0.634159 -0.809020 -0.274106 -0.666163 -1.477584 -0.476590  0.671575
# 4  0.634378 -0.809834 -0.273313 -0.663127 -1.492872 -0.505572  0.672169
#
#    feature7  feature8  feature9  ...  feature15  feature16  feature17  \
# 0 -1.593898 -0.737468 -0.707356  ...  -0.806243  -1.897467  -0.689874
# 1 -1.595835 -0.737365 -0.706467  ...  -0.804118  -1.922840  -0.700692
# 2 -1.597528 -0.735672 -0.712429  ...  -0.805056  -1.912729  -0.702529
# 3 -1.599879 -0.736326 -0.715938  ...  -0.803497  -1.930459  -0.711766
# 4 -1.601423 -0.736355 -0.715920  ...  -0.803804  -1.935742  -0.727374
#
#    feature18  feature19  feature20  feature21  feature22  feature23  \
# ...

# %%
data1.insert(0, 'SEQUENCE_ID', range(0, len(data1)))

# %%
data1.head()
# Out:
#    SEQUENCE_ID  feature1  feature2  feature2  feature3  feature4  feature5  \
# 0            0  0.631310 -0.807240 -0.279330 -0.630195 -1.451361 -0.465686
# 1            1  0.632066 -0.807258 -0.278007 -0.626388 -1.464355 -0.474674
# 2            2  0.633518 -0.807240 -0.274849 -0.642930 -1.462434 -0.474046
# 3            3  0.634159 -0.809020 -0.274106 -0.666163 -1.477584 -0.476590
# 4            4  0.634378 -0.809834 -0.273313 -0.663127 -1.492872 -0.505572
#
#    feature6  feature7  feature8  ...  feature15  feature16  feature17  \
# 0  0.665998 -1.593898 -0.737468  ...  -0.806243  -1.897467  -0.689874
# 1  0.666855 -1.595835 -0.737365  ...  -0.804118  -1.922840  -0.700692
# 2  0.669992 -1.597528 -0.735672  ...  -0.805056  -1.912729  -0.702529
# 3  0.671575 -1.599879 -0.736326  ...  -0.803497  -1.930459  -0.711766
# 4  0.672169 -1.601423 -0.736355  ...  -0.803804  -1.935742  -0.727374
#
#    feature18  feature19  feature20  feature21  feature22  feature23  \
# ...

# %%
data1.insert(26, 'IS_TEST', 0)

# %%
data1.head()
# Out:
#    SEQUENCE_ID  feature1  feature2  feature2  feature3  feature4  feature5  \
# 0            0  0.631310 -0.807240 -0.279330 -0.630195 -1.451361 -0.465686
# 1            1  0.632066 -0.807258 -0.278007 -0.626388 -1.464355 -0.474674
# 2            2  0.633518 -0.807240 -0.274849 -0.642930 -1.462434 -0.474046
# 3            3  0.634159 -0.809020 -0.274106 -0.666163 -1.477584 -0.476590
# 4            4  0.634378 -0.809834 -0.273313 -0.663127 -1.492872 -0.505572
#
#    feature6  feature7  feature8  ...  feature16  feature17  feature18  \
# 0  0.665998 -1.593898 -0.737468  ...  -1.897467  -0.689874   0.597063
# 1  0.666855 -1.595835 -0.737365  ...  -1.922840  -0.700692   0.594941
# 2  0.669992 -1.597528 -0.735672  ...  -1.912729  -0.702529   0.599973
# 3  0.671575 -1.599879 -0.736326  ...  -1.930459  -0.711766   0.605679
# 4  0.672169 -1.601423 -0.736355  ...  -1.935742  -0.727374   0.597675
#
#    feature19  feature20  feature21  feature22  feature23  \
# ...

# %%
big_data_frame1 = data1

# %%
big_data_frame1.head()
# Out:
#    SEQUENCE_ID  feature1  feature2  feature2  feature3  feature4  feature5  \
# 0            0  0.631310 -0.807240 -0.279330 -0.630195 -1.451361 -0.465686
# 1            1  0.632066 -0.807258 -0.278007 -0.626388 -1.464355 -0.474674
# 2            2  0.633518 -0.807240 -0.274849 -0.642930 -1.462434 -0.474046
# 3            3  0.634159 -0.809020 -0.274106 -0.666163 -1.477584 -0.476590
# 4            4  0.634378 -0.809834 -0.273313 -0.663127 -1.492872 -0.505572
#
#    feature6  feature7  feature8  ...  feature16  feature17  feature18  \
# 0  0.665998 -1.593898 -0.737468  ...  -1.897467  -0.689874   0.597063
# 1  0.666855 -1.595835 -0.737365  ...  -1.922840  -0.700692   0.594941
# 2  0.669992 -1.597528 -0.735672  ...  -1.912729  -0.702529   0.599973
# 3  0.671575 -1.599879 -0.736326  ...  -1.930459  -0.711766   0.605679
# 4  0.672169 -1.601423 -0.736355  ...  -1.935742  -0.727374   0.597675
#
#    feature19  feature20  feature21  feature22  feature23  \
# ...

# %%
big_data_frame2 = reshaped_data_frames[1]

# %%
big_data_frame2.rename(columns = {0:'feature1'}, inplace = True)

# %%
temp_column = reshaped_data_frames[3]
data2 = pd.concat([big_data_frame2,temp_column], axis = 1)

# %%
v = 0
for i in range(4,50):
    if i%2 != 0:
        temp_column = reshaped_data_frames[i]
        data2 = pd.concat([data2,temp_column], axis = 1)
        data2.rename(columns = {0:name[v]}, inplace = True)
        v+=1

# %%
big_data_frame1
# Out:
#       SEQUENCE_ID  feature1  feature2  feature2  feature3  feature4  feature5  \
# 0               0  0.631310 -0.807240 -0.279330 -0.630195 -1.451361 -0.465686
# 1               1  0.632066 -0.807258 -0.278007 -0.626388 -1.464355 -0.474674
# 2               2  0.633518 -0.807240 -0.274849 -0.642930 -1.462434 -0.474046
# 3               3  0.634159 -0.809020 -0.274106 -0.666163 -1.477584 -0.476590
# 4               4  0.634378 -0.809834 -0.273313 -0.663127 -1.492872 -0.505572
# ...           ...       ...       ...       ...       ...       ...       ...
# 9535         9535       NaN       NaN       NaN       NaN       NaN       NaN
# 9536         9536       NaN       NaN       NaN       NaN       NaN       NaN
# 9537         9537       NaN       NaN       NaN       NaN       NaN       NaN
# 9538         9538       NaN       NaN       NaN       NaN       NaN       NaN
# 9539         9539       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
data2.insert(0, 'SEQUENCE_ID', range(9540, 9540+len(data2)))

# %%
data2.insert(26, 'IS_TEST', 1)

# %%
data2.head()
# Out:
#    SEQUENCE_ID  feature1  feature2  feature2  feature3  feature4  feature5  \
# 0         9540  0.599967 -0.823936 -0.286140 -0.507478 -1.369001 -0.515990
# 1         9541  0.597535 -0.822723 -0.285675 -0.489377 -1.382364 -0.537491
# 2         9542  0.597007 -0.820954 -0.285412 -0.510865 -1.371936 -0.510966
# 3         9543  0.599099 -0.822648 -0.285793 -0.506752 -1.383616 -0.530980
# 4         9544  0.606181 -0.826938 -0.290546 -0.529976 -1.560801 -0.658221
#
#    feature6  feature7  feature8  ...  feature16  feature17  feature18  \
# 0  0.577993 -1.534954 -0.673190  ...  -1.821679  -0.846321   0.465208
# 1  0.576627 -1.532795 -0.671919  ...  -1.841987  -0.846325   0.467033
# 2  0.576456 -1.532478 -0.671555  ...  -1.821358  -0.839571   0.471135
# 3  0.579362 -1.535441 -0.672198  ...  -1.845643  -0.848031   0.506153
# 4  0.626759 -1.482552 -0.659393  ...  -1.941721  -0.885500   0.611207
#
#    feature19  feature20  feature21  feature22  feature23  \
# ...

# %%
big_data_frame2 = data2

# %%
big_data_frame2.head()
# Out:
#    SEQUENCE_ID  feature1  feature2  feature2  feature3  feature4  feature5  \
# 0         9540  0.599967 -0.823936 -0.286140 -0.507478 -1.369001 -0.515990
# 1         9541  0.597535 -0.822723 -0.285675 -0.489377 -1.382364 -0.537491
# 2         9542  0.597007 -0.820954 -0.285412 -0.510865 -1.371936 -0.510966
# 3         9543  0.599099 -0.822648 -0.285793 -0.506752 -1.383616 -0.530980
# 4         9544  0.606181 -0.826938 -0.290546 -0.529976 -1.560801 -0.658221
#
#    feature6  feature7  feature8  ...  feature16  feature17  feature18  \
# 0  0.577993 -1.534954 -0.673190  ...  -1.821679  -0.846321   0.465208
# 1  0.576627 -1.532795 -0.671919  ...  -1.841987  -0.846325   0.467033
# 2  0.576456 -1.532478 -0.671555  ...  -1.821358  -0.839571   0.471135
# 3  0.579362 -1.535441 -0.672198  ...  -1.845643  -0.848031   0.506153
# 4  0.626759 -1.482552 -0.659393  ...  -1.941721  -0.885500   0.611207
#
#    feature19  feature20  feature21  feature22  feature23  \
# ...

# %%
dframes = [big_data_frame1,big_data_frame2]
final_df = pd.concat(dframes)

# %%
final_df.head()
# Out:
#    SEQUENCE_ID  feature1  feature2  feature2  feature3  feature4  feature5  \
# 0            0  0.631310 -0.807240 -0.279330 -0.630195 -1.451361 -0.465686
# 1            1  0.632066 -0.807258 -0.278007 -0.626388 -1.464355 -0.474674
# 2            2  0.633518 -0.807240 -0.274849 -0.642930 -1.462434 -0.474046
# 3            3  0.634159 -0.809020 -0.274106 -0.666163 -1.477584 -0.476590
# 4            4  0.634378 -0.809834 -0.273313 -0.663127 -1.492872 -0.505572
#
#    feature6  feature7  feature8  ...  feature16  feature17  feature18  \
# 0  0.665998 -1.593898 -0.737468  ...  -1.897467  -0.689874   0.597063
# 1  0.666855 -1.595835 -0.737365  ...  -1.922840  -0.700692   0.594941
# 2  0.669992 -1.597528 -0.735672  ...  -1.912729  -0.702529   0.599973
# 3  0.671575 -1.599879 -0.736326  ...  -1.930459  -0.711766   0.605679
# 4  0.672169 -1.601423 -0.736355  ...  -1.935742  -0.727374   0.597675
#
#    feature19  feature20  feature21  feature22  feature23  \
# ...
